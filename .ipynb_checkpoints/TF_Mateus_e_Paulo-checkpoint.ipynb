# %%
# !pip3 install ipython-autotime

# %load_ext autotime
# Out:
# Requirement already satisfied: ipython-autotime in /home/paulo/.local/lib/python3.8/site-packages (0.1)
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 1.53 s

# %% [markdown]
# ## Análise dos dados

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('bank-full.csv',sep=';')
df.head(10)
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   58    management   married   tertiary      no     2143     yes   no
# 1   44    technician    single  secondary      no       29     yes   no
# 2   33  entrepreneur   married  secondary      no        2     yes  yes
# 3   47   blue-collar   married    unknown      no     1506     yes   no
# 4   33       unknown    single    unknown      no        1      no   no
# 5   35    management   married   tertiary      no      231     yes   no
# 6   28    management    single   tertiary      no      447     yes  yes
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8   58       retired   married    primary      no      121     yes   no
# 9   43    technician    single  secondary      no      593     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
# 5  unknown    5   may       139         1     -1         0  unknown  no
# 6  unknown    5   may       217         1     -1         0  unknown  no
# 7  unknown    5   may       380         1     -1         0  unknown  no
# 8  unknown    5   may        50         1     -1         0  unknown  no
# 9  unknown    5   may        55         1     -1         0  unknown  no
# time: 102 ms

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# time: 33.7 ms

# %%
df['y'].value_counts()
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int64
# time: 9.41 ms

# %% [markdown]
# # Pré-processamento

# %%
from sklearn.impute          import SimpleImputer
from sklearn.preprocessing   import StandardScaler
from sklearn.preprocessing   import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.pipeline        import Pipeline
from sklearn.compose         import ColumnTransformer

# Renomeando coluna alvo 
df.rename(columns={'y': 'subscribed_term_deposit'}, inplace=True)
# Renomeando coluna default  
df.rename(columns={'default': 'credit_in_default'}, inplace=True)

# Transformando coluna default em uma única coluna binária
df['credit_in_default_bin'] = 0
df.loc[df['credit_in_default']=='yes','credit_in_default_bin'] = 1

# Transformando housing em uma única coluna binária
df['housing_bin'] = 0
df.loc[df['housing']=='yes','housing_bin'] = 1

# Transformando loan em uma única coluna binária
df['loan_bin'] = 0
df.loc[df['loan']=='yes','loan'] = 1

atributos_numericos = ['age','balance','day','duration','campaign','pdays','previous']
atributos_binarios  = ['credit_in_default_bin','housing_bin','loan_bin']
atributos_categoricos = ['job', 'marital','education', 'contact', 'month', 'poutcome']
nome_coluna_alvo = ['subscribed_term_deposit']

# separando os conjuntos de dados de treino e teste
df_treino, df_teste = train_test_split(df, test_size=0.2, random_state=42)

# separando a coluna alvo do conjunto de treino
df_treino_labels = df_treino[nome_coluna_alvo].copy()
df_treino        = df_treino.drop(columns=nome_coluna_alvo)

# separando a coluna alvo do conjunto de teste
df_teste_labels = df_teste[nome_coluna_alvo].copy()
df_teste        = df_teste.drop(columns=nome_coluna_alvo)


# Pipelines de Pré-processamento
pipeline_atr_numericos = Pipeline([
    ('imputer',SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
])

preproc_completo = ColumnTransformer([
    ('numericos',   pipeline_atr_numericos, atributos_numericos   ),
    ('binarios',    'passthrough',          atributos_binarios    ),
    ('categoricos', OneHotEncoder(),        atributos_categoricos ),
    ],
    sparse_threshold=0)

# pre-processamento do conjunto de treino
X_treino = preproc_completo.fit_transform(df_treino)

# pre-processamento do conjunto de teste
X_teste = preproc_completo.transform(df_teste)
    
# Coluna alvo para os conjuntos de treino e teste
y_treino = df_treino_labels[ nome_coluna_alvo ] == 'yes'
y_treino = y_treino.values.ravel()

y_teste  = df_teste_labels[  nome_coluna_alvo ] == 'yes'
y_teste  = y_teste.values.ravel()

nomes_atributos = atributos_numericos
nomes_atributos = np.append( nomes_atributos, atributos_binarios )
nomes_atributos = np.append( nomes_atributos,
                             preproc_completo.named_transformers_['categoricos'].get_feature_names())
# Out:
# time: 948 ms

# %%
X_treino.shape, y_treino.shape
# Out:
# ((36168, 48), (36168,))
# time: 4.49 ms

# %%
y_treino
# Out:
# array([False, False, False, ..., False, False, False])
# time: 4.58 ms

# %%
valores_y_treino, quantidades_y_treino = np.unique(y_treino, return_counts=True)
print(np.asarray((valores_y_treino, quantidades_y_treino)))
print("Proporção classe True: ",quantidades_y_treino[1]/y_treino.shape[0])
# Out:
# [[    0     1]
#  [31970  4198]]
# Proporção classe True:  0.11606945366069453
# time: 2 ms

# %%
X_teste.shape, y_teste.shape
# Out:
# ((9043, 48), (9043,))
# time: 2.27 ms

# %%
valores_y_teste, quantidades_y_teste = np.unique(y_teste, return_counts=True)
print(np.asarray((valores_y_teste, quantidades_y_teste)))
print("Proporção classe True: ",quantidades_y_teste[1]/y_teste.shape[0])
# Out:
# [[   0    1]
#  [7952 1091]]
# Proporção classe True:  0.1206458033838328
# time: 1.68 ms

# %%
nomes_atributos
# Out:
# array(['age', 'balance', 'day', 'duration', 'campaign', 'pdays',
#        'previous', 'credit_in_default_bin', 'housing_bin', 'loan_bin',
#        'x0_admin.', 'x0_blue-collar', 'x0_entrepreneur', 'x0_housemaid',
#        'x0_management', 'x0_retired', 'x0_self-employed', 'x0_services',
#        'x0_student', 'x0_technician', 'x0_unemployed', 'x0_unknown',
#        'x1_divorced', 'x1_married', 'x1_single', 'x2_primary',
#        'x2_secondary', 'x2_tertiary', 'x2_unknown', 'x3_cellular',
#        'x3_telephone', 'x3_unknown', 'x4_apr', 'x4_aug', 'x4_dec',
#        'x4_feb', 'x4_jan', 'x4_jul', 'x4_jun', 'x4_mar', 'x4_may',
#        'x4_nov', 'x4_oct', 'x4_sep', 'x5_failure', 'x5_other',
#        'x5_success', 'x5_unknown'], dtype=object)
# time: 4.73 ms

# %% [markdown]
# ## Treinamento e avaliação de desempenho

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# time: 993 µs

# %% [markdown]
# ### Regressão logística apenas para fins de comparação para os próximos passos

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(X_treino, y_treino)

y_previsto = log_reg.predict(X_teste)

print("Acurácia: ", accuracy_score(y_teste,y_previsto))
print("Precisão: ", precision_score(y_teste,y_previsto))
print("Recall:   ", recall_score(y_teste,y_previsto))
print("F1 Score: ", f1_score(y_teste,y_previsto))
# Out:
# Acurácia:  0.899037929890523
# Precisão:  0.6539792387543253
# Recall:    0.3464711274060495
# F1 Score:  0.45296584781306176
# time: 564 ms

# %% [markdown]
# ## Treinamento de uma RNA tipo Multi-Layer Perceptron

# %%
from sklearn.neural_network import MLPClassifier

mlp_clf = MLPClassifier(hidden_layer_sizes=(20))
mlp_clf.fit(X_treino, y_treino)

y_previsto = mlp_clf.predict(X_teste)
print("MLP:")
print("Acurácia: ", accuracy_score(y_teste,y_previsto))
print("Precisão: ", precision_score(y_teste,y_previsto))
print("Recall:   ", recall_score(y_teste,y_previsto))
print("F1 Score: ", f1_score(y_teste,y_previsto))
# Out:
# MLP:
# Acurácia:  0.906668141103616
# Precisão:  0.6376811594202898
# Recall:    0.5242896425297892
# F1 Score:  0.5754527162977867
# time: 27.9 s

# %% [markdown]
# ## Testando diferentes RNA's usando MLP
#
# Utilizamos a tecnica de GridSearchCV que foi ensinada em aula para fazer a descoberta da melhor arquitetura das redes escolhidas. Como nosso dataset possui poucas colunas e como pode ser visto um pouco mais acima, foi gerado um modelo com apenas 48 colunas possíveis optamos por não colocar números muito distante desse valor. Apenas 1 teste foi feito com 100 neuronios para fim de comparação/curiosidade

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
 {'hidden_layer_sizes': [(10,), (20,), (20,20), (50,50), (50,20), (100,100), (30,30,30) ], 
  'activation': ['logistic', 'tanh', 'relu']},
 ]

mlp_clf = MLPClassifier()

grid_search = GridSearchCV(mlp_clf, param_grid)
grid_search.fit(X_treino, y_treino)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# GridSearchCV(cv=None, error_score=nan,
#              estimator=MLPClassifier(activation='relu', alpha=0.0001,
#                                      batch_size='auto', beta_1=0.9,
#                                      beta_2=0.999, early_stopping=False,
#                                      epsilon=1e-08, hidden_layer_sizes=(100,),
#                                      learning_rate='constant',
#                                      learning_rate_init=0.001, max_fun=15000,
#                                      max_iter=200, momentum=0.9,
#                                      n_iter_no_change=10,
#                                      nesterovs_momentum=True, power_t=0.5,
#                                      random_state=None, shuffle=True,
#                                      solver='adam', tol=0.0001,
#                                      validation_fraction=0.1, verbose=False,
#                                      warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'activation': ['logistic', 'tanh', 'relu'],
#                           'hidden_layer_sizes': [(10,), (20,), (20, 20),
#                                                  (50, 50), (50, 20), (100, 100),
#                                                  (30, 30, 30)]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# time: 1h 12min 38s

# %%
grid_search.best_params_
# Out:
# {'activation': 'logistic', 'hidden_layer_sizes': (20,)}
# time: 2.64 ms

# %%
y_previsto = grid_search.best_estimator_.predict(X_teste)
print("Best MLP:")
print("Acurácia: ", accuracy_score(y_teste,y_previsto))
print("Precisão: ", precision_score(y_teste,y_previsto))
print("Recall:   ", recall_score(y_teste,y_previsto))
print("F1 Score: ", f1_score(y_teste,y_previsto))
# Out:
# Best MLP:
# Acurácia:  0.9091009620701095
# Precisão:  0.6530147895335608
# Recall:    0.5261228230980751
# F1 Score:  0.582741116751269
# time: 36.7 ms

# %% [markdown]
# ## Treinamento usando Keras + TensorFlow

# %%
import tensorflow as tf
from tensorflow import keras
tf.__version__, keras.__version__
# Out:
# ('2.2.0', '2.3.0-tf')
# time: 1.36 s

# %%
X_treino.shape[1:]
# Out:
# (48,)
# time: 2.07 ms

# %% [markdown]
# ### Construindo o modelo a ser treinado

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(20, activation="relu",input_shape=X_treino.shape[1:]))
model.add(keras.layers.Dense(20, activation="relu"))
model.add(keras.layers.Dense(2, activation="softmax"))
# Out:
# time: 38.8 ms

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_43 (Dense)             (None, 20)                980
# _________________________________________________________________
# dense_44 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_45 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 1,442
# Trainable params: 1,442
# Non-trainable params: 0
# _________________________________________________________________
# time: 2.89 ms

# %%
# Para modelos de classificação com saída esparsa:    # para classificação com saída densa  # para classificação binária:     
model.compile(loss="sparse_categorical_crossentropy", # usar categorical_crossentropy       # usar binary_crossentropy e mudar
              optimizer="sgd",                        #                                     # a ativação da camada de saída
              metrics=["accuracy"])                   #                                     # para sigmoid

# Para modelos de regressão deixar a última camada com um
# único neurônio sem ativação e usar loss="mean_squared_error"
# Out:
# time: 7.91 ms

# %% [markdown]
# ### Treinando o modelo

# %%
history = model.fit(X_treino, y_treino, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3020 - accuracy: 0.8825 - val_loss: 0.2582 - val_accuracy: 0.8930
# Epoch 2/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2538 - accuracy: 0.8937 - val_loss: 0.2412 - val_accuracy: 0.8959
# Epoch 3/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2407 - accuracy: 0.8972 - val_loss: 0.2329 - val_accuracy: 0.8976
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2335 - accuracy: 0.8983 - val_loss: 0.2285 - val_accuracy: 0.8985
# Epoch 5/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2294 - accuracy: 0.8994 - val_loss: 0.2252 - val_accuracy: 0.8989
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2267 - accuracy: 0.9007 - val_loss: 0.2230 - val_accuracy: 0.9002
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2245 - accuracy: 0.9013 - val_loss: 0.2214 - val_accuracy: 0.9001
# Epoch 8/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2232 - accuracy: 0.9011 - val_loss: 0.2199 - val_accuracy: 0.9006
# Epoch 9/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2220 - accuracy: 0.9022 - val_loss: 0.2193 - val_accuracy: 0.9013
# Epoch 10/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2211 - accuracy: 0.9029 - val_loss: 0.2184 - val_accuracy: 0.9023
# time: 14.6 s

# %%
pd.DataFrame(history.history).plot(figsize=(10,6))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()
# Out:
# time: 192 ms

# %% [markdown]
# ### Avaliando o desempenho do modelo treinado

# %%
y_previsto_rna_proba = model.predict(X_teste)
# Out:
# time: 193 ms

# %%
np.round(y_previsto_rna_proba,decimals=2)
# Out:
# array([[1.  , 0.  ],
#        [0.99, 0.01],
#        [0.72, 0.28],
#        ...,
#        [0.99, 0.01],
#        [1.  , 0.  ],
#        [0.98, 0.02]], dtype=float32)
# time: 4.08 ms

# %%
y_previsto_rna = model.predict_classes(X_teste)
y_previsto_rna
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
# time: 155 ms

# %%
print("RNA:")
print("Acurácia: ", accuracy_score(y_teste,y_previsto_rna))
print("Precisão: ", precision_score(y_teste,y_previsto_rna))
print("Recall:   ", recall_score(y_teste,y_previsto_rna))
print("F1 Score: ", f1_score(y_teste,y_previsto_rna))
# Out:
# RNA:
# Acurácia:  0.8991485126617274
# Precisão:  0.618229854689564
# Recall:    0.42896425297891844
# F1 Score:  0.5064935064935066
# time: 22.6 ms

# %% [markdown]
# ### Early Stopping
#
# Aplicamos a técinca ensinada em aula para procurar o melhor modelo e faer que o algoritmo pare de executar assim que não detectar nenhuma melhora significativa.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Dense(100, activation="relu",input_shape=X_treino.shape[1:]))
model.add(keras.layers.Dense(20, activation="relu"))
model.add(keras.layers.Dense(20, activation="relu"))
model.add(keras.layers.Dense(20, activation="relu"))
model.add(keras.layers.Dense(2, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
                optimizer="sgd",
                metrics=["accuracy"])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=4,restore_best_weights=True)

history = model.fit(X_treino, y_treino, epochs=100, validation_split=0.2,callbacks=[early_stopping_cb])

print("RNA:")
print("Acurácia: ", accuracy_score(y_teste,y_previsto_rna))
print("Precisão: ", precision_score(y_teste,y_previsto_rna))
print("Recall:   ", recall_score(y_teste,y_previsto_rna))
print("F1 Score: ", f1_score(y_teste,y_previsto_rna))

pd.DataFrame(history.history).plot(figsize=(10,6))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()
# Out:
# Epoch 1/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3345 - accuracy: 0.8787 - val_loss: 0.2577 - val_accuracy: 0.8826
# Epoch 2/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2433 - accuracy: 0.8906 - val_loss: 0.2287 - val_accuracy: 0.8972
# Epoch 3/100
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2286 - accuracy: 0.8969 - val_loss: 0.2221 - val_accuracy: 0.9023
# Epoch 4/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2218 - accuracy: 0.9005 - val_loss: 0.2173 - val_accuracy: 0.9032
# Epoch 5/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2176 - accuracy: 0.9029 - val_loss: 0.2145 - val_accuracy: 0.9030
# Epoch 6/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2145 - accuracy: 0.9037 - val_loss: 0.2167 - val_accuracy: 0.9012
# Epoch 7/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2123 - accuracy: 0.9047 - val_loss: 0.2112 - val_accuracy: 0.9060
# Epoch 8/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2103 - accuracy: 0.9057 - val_loss: 0.2106 - val_accuracy: 0.9059
# Epoch 9/100
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2082 - accuracy: 0.9057 - val_loss: 0.2102 - val_accuracy: 0.9045
# Epoch 10/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2067 - accuracy: 0.9060 - val_loss: 0.2092 - val_accuracy: 0.9074
# Epoch 11/100
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2051 - accuracy: 0.9061 - val_loss: 0.2102 - val_accuracy: 0.9078
# Epoch 12/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2035 - accuracy: 0.9078 - val_loss: 0.2065 - val_accuracy: 0.9063
# Epoch 13/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2021 - accuracy: 0.9074 - val_loss: 0.2073 - val_accuracy: 0.9067
# Epoch 14/100
# 905/905 [==============================] - 2s 3ms/step - loss: 0.2009 - accuracy: 0.9083 - val_loss: 0.2050 - val_accuracy: 0.9075
# Epoch 15/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1990 - accuracy: 0.9089 - val_loss: 0.2061 - val_accuracy: 0.9077
# Epoch 16/100
# 905/905 [==============================] - 3s 3ms/step - loss: 0.1978 - accuracy: 0.9101 - val_loss: 0.2055 - val_accuracy: 0.9064
# Epoch 17/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1963 - accuracy: 0.9105 - val_loss: 0.2063 - val_accuracy: 0.9050
# Epoch 18/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1953 - accuracy: 0.9099 - val_loss: 0.2049 - val_accuracy: 0.9070
# Epoch 19/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1940 - accuracy: 0.9109 - val_loss: 0.2068 - val_accuracy: 0.9077
# Epoch 20/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1929 - accuracy: 0.9120 - val_loss: 0.2090 - val_accuracy: 0.9067
# Epoch 21/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1920 - accuracy: 0.9116 - val_loss: 0.2037 - val_accuracy: 0.9052
# Epoch 22/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1907 - accuracy: 0.9123 - val_loss: 0.2035 - val_accuracy: 0.9052
# Epoch 23/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1900 - accuracy: 0.9136 - val_loss: 0.2030 - val_accuracy: 0.9057
# Epoch 24/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1887 - accuracy: 0.9133 - val_loss: 0.2054 - val_accuracy: 0.9077
# Epoch 25/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1880 - accuracy: 0.9131 - val_loss: 0.2029 - val_accuracy: 0.9077
# Epoch 26/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1867 - accuracy: 0.9151 - val_loss: 0.2053 - val_accuracy: 0.9028
# Epoch 27/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1857 - accuracy: 0.9147 - val_loss: 0.2079 - val_accuracy: 0.9053
# Epoch 28/100
# 905/905 [==============================] - 2s 2ms/step - loss: 0.1850 - accuracy: 0.9152 - val_loss: 0.2067 - val_accuracy: 0.9024
# Epoch 29/100
# 905/905 [==============================] - 2s 3ms/step - loss: 0.1844 - accuracy: 0.9159 - val_loss: 0.2086 - val_accuracy: 0.8994
# RNA:
# Acurácia:  0.9050093995355524
# Precisão:  0.6530343007915568
# Recall:    0.4537121906507791
# F1 Score:  0.5354245538128719
# time: 59.7 s

# %% [markdown]
# ### Grid Search

# %%
def MLPKerasTF(hidden_layer_sizes=(20),activation="relu"):
    model = keras.models.Sequential()
    model.add(keras.layers.InputLayer(input_shape=X_treino.shape[1:]))
    for units in hidden_layer_sizes:
        model.add(keras.layers.Dense(units,activation=activation))
    model.add(keras.layers.Dense(2, activation="softmax"))
    model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])
    model.summary()
    print("activation=",activation)
    return model

mlpKerasTF_clf = keras.wrappers.scikit_learn.KerasClassifier(MLPKerasTF)
# Out:
# time: 1.27 ms

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
 {'hidden_layer_sizes':[(10,), (20,), (20,20), (50,50), (20,10,5), (40,20,5), (100,50,10)],
  'activation': ['sigmoid', 'tanh', 'relu']},
 ]

grid_search = GridSearchCV(mlpKerasTF_clf, param_grid)
grid_search.fit(X_treino, y_treino, epochs=10)
# Out:
# Model: "sequential_938"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3119 (Dense)           (None, 10)                490
# _________________________________________________________________
# dense_3120 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 512
# Trainable params: 512
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 1ms/step - loss: 0.3591 - accuracy: 0.8825
# Epoch 2/10
# 905/905 [==============================] - 1s 1ms/step - loss: 0.3211 - accuracy: 0.8827
# Epoch 3/10
# 905/905 [==============================] - 1s 1ms/step - loss: 0.2992 - accuracy: 0.8840
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2837 - accuracy: 0.8867
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2734 - accuracy: 0.8892
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2665 - accuracy: 0.8904
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2616 - accuracy: 0.8923
# Epoch 8/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2579 - accuracy: 0.8927
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2550 - accuracy: 0.8932
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2525 - accuracy: 0.8932
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2421 - accuracy: 0.8959
# Model: "sequential_939"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3121 (Dense)           (None, 10)                490
# _________________________________________________________________
# dense_3122 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 512
# Trainable params: 512
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3561 - accuracy: 0.8764
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3018 - accuracy: 0.8859
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2794 - accuracy: 0.8896
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2667 - accuracy: 0.8928
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2594 - accuracy: 0.8943
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2546 - accuracy: 0.8949
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2511 - accuracy: 0.8951
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2484 - accuracy: 0.8959
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2461 - accuracy: 0.8961
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2441 - accuracy: 0.8966
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2618 - accuracy: 0.8840
# Model: "sequential_940"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3123 (Dense)           (None, 10)                490
# _________________________________________________________________
# dense_3124 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 512
# Trainable params: 512
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3829 - accuracy: 0.8803
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3330 - accuracy: 0.8837
# Epoch 3/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3059 - accuracy: 0.8839
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2855 - accuracy: 0.8856
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2717 - accuracy: 0.8885
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2631 - accuracy: 0.8911
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2576 - accuracy: 0.8919
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2539 - accuracy: 0.8924
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2512 - accuracy: 0.8935
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2490 - accuracy: 0.8938
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.8970
# Model: "sequential_941"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3125 (Dense)           (None, 10)                490
# _________________________________________________________________
# dense_3126 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 512
# Trainable params: 512
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3432 - accuracy: 0.8828
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3070 - accuracy: 0.8829
# Epoch 3/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2847 - accuracy: 0.8848
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2709 - accuracy: 0.8875
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2625 - accuracy: 0.8898
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2571 - accuracy: 0.8904
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2534 - accuracy: 0.8910
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2506 - accuracy: 0.8921
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2483 - accuracy: 0.8929
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2463 - accuracy: 0.8935
# 227/227 [==============================] - 0s 1ms/step - loss: 0.2420 - accuracy: 0.8971
# Model: "sequential_942"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3127 (Dense)           (None, 10)                490
# _________________________________________________________________
# dense_3128 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 512
# Trainable params: 512
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3227 - accuracy: 0.8843
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2904 - accuracy: 0.8865
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2747 - accuracy: 0.8889
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2660 - accuracy: 0.8903
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2606 - accuracy: 0.8925
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2566 - accuracy: 0.8928
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2535 - accuracy: 0.8937
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2509 - accuracy: 0.8940
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2487 - accuracy: 0.8948
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2467 - accuracy: 0.8949
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.9000
# Model: "sequential_943"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3129 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3130 (Dense)           (None, 2)                 42
# =================================================================
# Total params: 1,022
# Trainable params: 1,022
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3274 - accuracy: 0.8810
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2898 - accuracy: 0.8857
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2743 - accuracy: 0.8890
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2660 - accuracy: 0.8921
# Epoch 5/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2609 - accuracy: 0.8932
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2573 - accuracy: 0.8941
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2546 - accuracy: 0.8949
# Epoch 8/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2523 - accuracy: 0.8956
# Epoch 9/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2503 - accuracy: 0.8968
# Epoch 10/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2485 - accuracy: 0.8968
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2398 - accuracy: 0.8972
# Model: "sequential_944"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3131 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3132 (Dense)           (None, 2)                 42
# =================================================================
# Total params: 1,022
# Trainable params: 1,022
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3813 - accuracy: 0.8565
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3108 - accuracy: 0.8860
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2916 - accuracy: 0.8885
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2783 - accuracy: 0.8909
# Epoch 5/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2696 - accuracy: 0.8928
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2636 - accuracy: 0.8941
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2593 - accuracy: 0.8948
# Epoch 8/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2559 - accuracy: 0.8953
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2531 - accuracy: 0.8957
# Epoch 10/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2507 - accuracy: 0.8959
# 227/227 [==============================] - 0s 1ms/step - loss: 0.2703 - accuracy: 0.8832
# Model: "sequential_945"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3133 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3134 (Dense)           (None, 2)                 42
# =================================================================
# Total params: 1,022
# Trainable params: 1,022
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3546 - accuracy: 0.8688
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2993 - accuracy: 0.8846
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2788 - accuracy: 0.8881
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2676 - accuracy: 0.8909
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2610 - accuracy: 0.8923
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2566 - accuracy: 0.8937
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2533 - accuracy: 0.8942
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2504 - accuracy: 0.8948
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2482 - accuracy: 0.8958
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2461 - accuracy: 0.8961
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2474 - accuracy: 0.8991
# Model: "sequential_946"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3135 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3136 (Dense)           (None, 2)                 42
# =================================================================
# Total params: 1,022
# Trainable params: 1,022
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3496 - accuracy: 0.8833
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3048 - accuracy: 0.8836
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2816 - accuracy: 0.8860
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2694 - accuracy: 0.8890
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2628 - accuracy: 0.8907
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2586 - accuracy: 0.8920
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2554 - accuracy: 0.8933
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2528 - accuracy: 0.8935
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2504 - accuracy: 0.8941
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2484 - accuracy: 0.8941
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2446 - accuracy: 0.8994
# Model: "sequential_947"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3137 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3138 (Dense)           (None, 2)                 42
# =================================================================
# Total params: 1,022
# Trainable params: 1,022
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3596 - accuracy: 0.8736
# Epoch 2/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3067 - accuracy: 0.8848
# Epoch 3/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2831 - accuracy: 0.8870
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2696 - accuracy: 0.8900
# Epoch 5/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2619 - accuracy: 0.8918
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2570 - accuracy: 0.8928
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2536 - accuracy: 0.8934
# Epoch 8/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2509 - accuracy: 0.8945
# Epoch 9/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2486 - accuracy: 0.8952
# Epoch 10/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2466 - accuracy: 0.8956
# 227/227 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.9000
# Model: "sequential_948"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3139 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3140 (Dense)           (None, 20)                420
# _________________________________________________________________
# dense_3141 (Dense)           (None, 2)                 42
# =================================================================
# Total params: 1,442
# Trainable params: 1,442
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3765 - accuracy: 0.8709
# Epoch 2/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3582 - accuracy: 0.8826
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3549 - accuracy: 0.8826
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3510 - accuracy: 0.8826
# Epoch 5/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3464 - accuracy: 0.8826
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3407 - accuracy: 0.8826
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3334 - accuracy: 0.8826
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3246 - accuracy: 0.8826
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3140 - accuracy: 0.8825
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3025 - accuracy: 0.8828
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2855 - accuracy: 0.8894
# Model: "sequential_949"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3142 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3143 (Dense)           (None, 20)                420
# _________________________________________________________________
# dense_3144 (Dense)           (None, 2)                 42
# =================================================================
# Total params: 1,442
# Trainable params: 1,442
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3678 - accuracy: 0.8730
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3424 - accuracy: 0.8858
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3328 - accuracy: 0.8858
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3211 - accuracy: 0.8858
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3067 - accuracy: 0.8858
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2915 - accuracy: 0.8858
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2775 - accuracy: 0.8877
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2664 - accuracy: 0.8910
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2587 - accuracy: 0.8940
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2536 - accuracy: 0.8959
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2709 - accuracy: 0.8824
# Model: "sequential_950"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3145 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3146 (Dense)           (None, 20)                420
# _________________________________________________________________
# dense_3147 (Dense)           (None, 2)                 42
# =================================================================
# Total params: 1,442
# Trainable params: 1,442
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3742 - accuracy: 0.8717
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3537 - accuracy: 0.8837
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3483 - accuracy: 0.8837
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3418 - accuracy: 0.8837
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3334 - accuracy: 0.8837
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3229 - accuracy: 0.8837
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3102 - accuracy: 0.8837
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2965 - accuracy: 0.8836
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2834 - accuracy: 0.8849
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2724 - accuracy: 0.8872
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2686 - accuracy: 0.8898
# Model: "sequential_951"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3148 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3149 (Dense)           (None, 20)                420
# _________________________________________________________________
# dense_3150 (Dense)           (None, 2)                 42
# =================================================================
# Total params: 1,442
# Trainable params: 1,442
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3767 - accuracy: 0.8747
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3583 - accuracy: 0.8833
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3521 - accuracy: 0.8833
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3448 - accuracy: 0.8833
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3356 - accuracy: 0.8833
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3239 - accuracy: 0.8833
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3099 - accuracy: 0.8833
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2948 - accuracy: 0.8835
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2811 - accuracy: 0.8853
# Epoch 10/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2705 - accuracy: 0.8887
# 227/227 [==============================] - 0s 1ms/step - loss: 0.2605 - accuracy: 0.8937
# Model: "sequential_952"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3151 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3152 (Dense)           (None, 20)                420
# _________________________________________________________________
# dense_3153 (Dense)           (None, 2)                 42
# =================================================================
# Total params: 1,442
# Trainable params: 1,442
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3566 - accuracy: 0.8843
# Epoch 2/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3507 - accuracy: 0.8843
# Epoch 3/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3467 - accuracy: 0.8843
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3419 - accuracy: 0.8843
# Epoch 5/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3358 - accuracy: 0.8843
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3282 - accuracy: 0.8843
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3188 - accuracy: 0.8843
# Epoch 8/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3082 - accuracy: 0.8843
# Epoch 9/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2970 - accuracy: 0.8847
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2867 - accuracy: 0.8864
# 227/227 [==============================] - 0s 1ms/step - loss: 0.2783 - accuracy: 0.8835
# Model: "sequential_953"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3154 (Dense)           (None, 50)                2450
# _________________________________________________________________
# dense_3155 (Dense)           (None, 50)                2550
# _________________________________________________________________
# dense_3156 (Dense)           (None, 2)                 102
# =================================================================
# Total params: 5,102
# Trainable params: 5,102
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3688 - accuracy: 0.8764
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3564 - accuracy: 0.8826
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3508 - accuracy: 0.8826
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3437 - accuracy: 0.8826
# Epoch 5/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3340 - accuracy: 0.8826
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3219 - accuracy: 0.8826
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3074 - accuracy: 0.8831
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2930 - accuracy: 0.8843
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2811 - accuracy: 0.8871
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2725 - accuracy: 0.8894
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2599 - accuracy: 0.8941
# Model: "sequential_954"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3157 (Dense)           (None, 50)                2450
# _________________________________________________________________
# dense_3158 (Dense)           (None, 50)                2550
# _________________________________________________________________
# dense_3159 (Dense)           (None, 2)                 102
# =================================================================
# Total params: 5,102
# Trainable params: 5,102
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3493 - accuracy: 0.8858
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3408 - accuracy: 0.8858
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3318 - accuracy: 0.8858
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3206 - accuracy: 0.8858
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3068 - accuracy: 0.8859
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2922 - accuracy: 0.8864
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2792 - accuracy: 0.8887
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2698 - accuracy: 0.8912
# Epoch 9/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2634 - accuracy: 0.8929
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2590 - accuracy: 0.8945
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2774 - accuracy: 0.8824
# Model: "sequential_955"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3160 (Dense)           (None, 50)                2450
# _________________________________________________________________
# dense_3161 (Dense)           (None, 50)                2550
# _________________________________________________________________
# dense_3162 (Dense)           (None, 2)                 102
# =================================================================
# Total params: 5,102
# Trainable params: 5,102
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3576 - accuracy: 0.8836
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3500 - accuracy: 0.8837
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3444 - accuracy: 0.8837
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3370 - accuracy: 0.8837
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3269 - accuracy: 0.8837
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3143 - accuracy: 0.8836
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3001 - accuracy: 0.8842
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2864 - accuracy: 0.8859
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2755 - accuracy: 0.8880
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2681 - accuracy: 0.8903
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2662 - accuracy: 0.8940
# Model: "sequential_956"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3163 (Dense)           (None, 50)                2450
# _________________________________________________________________
# dense_3164 (Dense)           (None, 50)                2550
# _________________________________________________________________
# dense_3165 (Dense)           (None, 2)                 102
# =================================================================
# Total params: 5,102
# Trainable params: 5,102
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3530 - accuracy: 0.8833
# Epoch 2/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3442 - accuracy: 0.8833
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3351 - accuracy: 0.8833
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3234 - accuracy: 0.8833
# Epoch 5/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3094 - accuracy: 0.8833
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2948 - accuracy: 0.8842
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2822 - accuracy: 0.8866
# Epoch 8/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2730 - accuracy: 0.8897
# Epoch 9/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2664 - accuracy: 0.8910
# Epoch 10/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2617 - accuracy: 0.8921
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2539 - accuracy: 0.8971
# Model: "sequential_957"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3166 (Dense)           (None, 50)                2450
# _________________________________________________________________
# dense_3167 (Dense)           (None, 50)                2550
# _________________________________________________________________
# dense_3168 (Dense)           (None, 2)                 102
# =================================================================
# Total params: 5,102
# Trainable params: 5,102
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3715 - accuracy: 0.8752
# Epoch 2/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3536 - accuracy: 0.8843
# Epoch 3/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3480 - accuracy: 0.8843
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3413 - accuracy: 0.8843
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3327 - accuracy: 0.8843
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3214 - accuracy: 0.8842
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3080 - accuracy: 0.8843
# Epoch 8/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2940 - accuracy: 0.8861
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2821 - accuracy: 0.8878
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2734 - accuracy: 0.8899
# 227/227 [==============================] - 0s 1ms/step - loss: 0.2667 - accuracy: 0.8913
# Model: "sequential_958"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3169 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3170 (Dense)           (None, 10)                210
# _________________________________________________________________
# dense_3171 (Dense)           (None, 5)                 55
# _________________________________________________________________
# dense_3172 (Dense)           (None, 2)                 12
# =================================================================
# Total params: 1,257
# Trainable params: 1,257
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3678 - accuracy: 0.8826
# Epoch 2/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3612 - accuracy: 0.8826
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3609 - accuracy: 0.8826
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3606 - accuracy: 0.8826
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3604 - accuracy: 0.8826
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3600 - accuracy: 0.8826
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3597 - accuracy: 0.8826
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3593 - accuracy: 0.8826
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3588 - accuracy: 0.8826
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3583 - accuracy: 0.8826
# 227/227 [==============================] - 0s 1ms/step - loss: 0.3443 - accuracy: 0.8894
# Model: "sequential_959"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3173 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3174 (Dense)           (None, 10)                210
# _________________________________________________________________
# dense_3175 (Dense)           (None, 5)                 55
# _________________________________________________________________
# dense_3176 (Dense)           (None, 2)                 12
# =================================================================
# Total params: 1,257
# Trainable params: 1,257
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3607 - accuracy: 0.8858
# Epoch 2/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3546 - accuracy: 0.8858
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3544 - accuracy: 0.8858
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3541 - accuracy: 0.8858
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3539 - accuracy: 0.8858
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3536 - accuracy: 0.8858
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3533 - accuracy: 0.8858
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3529 - accuracy: 0.8858
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3525 - accuracy: 0.8858
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3521 - accuracy: 0.8858
# 227/227 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.8764
# Model: "sequential_960"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3177 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3178 (Dense)           (None, 10)                210
# _________________________________________________________________
# dense_3179 (Dense)           (None, 5)                 55
# _________________________________________________________________
# dense_3180 (Dense)           (None, 2)                 12
# =================================================================
# Total params: 1,257
# Trainable params: 1,257
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3856 - accuracy: 0.8694
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3596 - accuracy: 0.8837
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3594 - accuracy: 0.8837
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3593 - accuracy: 0.8837
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3591 - accuracy: 0.8837
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3589 - accuracy: 0.8837
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3587 - accuracy: 0.8837
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3585 - accuracy: 0.8837
# Epoch 9/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3583 - accuracy: 0.8837
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3581 - accuracy: 0.8837
# 227/227 [==============================] - 0s 1ms/step - loss: 0.3553 - accuracy: 0.8850
# Model: "sequential_961"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3181 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3182 (Dense)           (None, 10)                210
# _________________________________________________________________
# dense_3183 (Dense)           (None, 5)                 55
# _________________________________________________________________
# dense_3184 (Dense)           (None, 2)                 12
# =================================================================
# Total params: 1,257
# Trainable params: 1,257
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3866 - accuracy: 0.8686
# Epoch 2/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3601 - accuracy: 0.8833
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3599 - accuracy: 0.8833
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3596 - accuracy: 0.8833
# Epoch 5/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3594 - accuracy: 0.8833
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3591 - accuracy: 0.8833
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3588 - accuracy: 0.8833
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3585 - accuracy: 0.8833
# Epoch 9/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3582 - accuracy: 0.8833
# Epoch 10/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3578 - accuracy: 0.8833
# 227/227 [==============================] - 0s 1ms/step - loss: 0.3513 - accuracy: 0.8864
# Model: "sequential_962"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3185 (Dense)           (None, 20)                980
# _________________________________________________________________
# dense_3186 (Dense)           (None, 10)                210
# _________________________________________________________________
# dense_3187 (Dense)           (None, 5)                 55
# _________________________________________________________________
# dense_3188 (Dense)           (None, 2)                 12
# =================================================================
# Total params: 1,257
# Trainable params: 1,257
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3880 - accuracy: 0.8656
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3586 - accuracy: 0.8843
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3585 - accuracy: 0.8843
# Epoch 4/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3584 - accuracy: 0.8843
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3584 - accuracy: 0.8843
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3583 - accuracy: 0.8843
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3582 - accuracy: 0.8843
# Epoch 8/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3581 - accuracy: 0.8843
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3581 - accuracy: 0.8843
# Epoch 10/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3580 - accuracy: 0.8843
# 227/227 [==============================] - 0s 2ms/step - loss: 0.3617 - accuracy: 0.8825
# Model: "sequential_963"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3189 (Dense)           (None, 40)                1960
# _________________________________________________________________
# dense_3190 (Dense)           (None, 20)                820
# _________________________________________________________________
# dense_3191 (Dense)           (None, 5)                 105
# _________________________________________________________________
# dense_3192 (Dense)           (None, 2)                 12
# =================================================================
# Total params: 2,897
# Trainable params: 2,897
# Non-trainable params: 0
# _________________________________________________________________
# activation= sigmoid
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3617 - accuracy: 0.8826
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3601 - accuracy: 0.8826
# Epoch 3/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3597 - accuracy: 0.8826
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3593 - accuracy: 0.8826
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3586 - accuracy: 0.8826
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3580 - accuracy: 0.8826
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3572 - accuracy: 0.8826
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3562 - accuracy: 0.8826
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3549 - accuracy: 0.8826
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3533 - accuracy: 0.8826
# 227/227 [==============================] - 0s 2ms/step - loss: 0.3394 - accuracy: 0.8894
# Model: "sequential_964"
# _________________________________________________________________
# ...
# dense_3422 (Dense)           (None, 20)                820
# _________________________________________________________________
# dense_3423 (Dense)           (None, 5)                 105
# _________________________________________________________________
# dense_3424 (Dense)           (None, 2)                 12
# =================================================================
# Total params: 2,897
# Trainable params: 2,897
# Non-trainable params: 0
# _________________________________________________________________
# activation= relu
# Epoch 1/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3914 - accuracy: 0.8833
# Epoch 2/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.3075 - accuracy: 0.8833
# Epoch 3/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2695 - accuracy: 0.8833
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2474 - accuracy: 0.8833
# Epoch 5/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2363 - accuracy: 0.8833
# Epoch 6/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2300 - accuracy: 0.8835
# Epoch 7/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2259 - accuracy: 0.8975
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2227 - accuracy: 0.8997
# Epoch 9/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2206 - accuracy: 0.9006
# Epoch 10/10
# 905/905 [==============================] - 1s 2ms/step - loss: 0.2186 - accuracy: 0.9014
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2198 - accuracy: 0.9042
# Model: "sequential_1037"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3425 (Dense)           (None, 40)                1960
# _________________________________________________________________
# dense_3426 (Dense)           (None, 20)                820
# _________________________________________________________________
# dense_3427 (Dense)           (None, 5)                 105
# _________________________________________________________________
# dense_3428 (Dense)           (None, 2)                 12
# =================================================================
# Total params: 2,897
# Trainable params: 2,897
# Non-trainable params: 0
# _________________________________________________________________
# activation= relu
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2810 - accuracy: 0.8866
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2380 - accuracy: 0.8949
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2302 - accuracy: 0.8968
# Epoch 4/10
# 905/905 [==============================] - 2s 3ms/step - loss: 0.2255 - accuracy: 0.8991
# Epoch 5/10
# 905/905 [==============================] - 2s 3ms/step - loss: 0.2225 - accuracy: 0.9005
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2200 - accuracy: 0.9007
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2179 - accuracy: 0.9016
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2161 - accuracy: 0.9036
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2146 - accuracy: 0.9039
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2129 - accuracy: 0.9044
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2168 - accuracy: 0.9025
# Model: "sequential_1038"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3429 (Dense)           (None, 100)               4900
# _________________________________________________________________
# dense_3430 (Dense)           (None, 50)                5050
# _________________________________________________________________
# dense_3431 (Dense)           (None, 10)                510
# _________________________________________________________________
# dense_3432 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 10,482
# Trainable params: 10,482
# Non-trainable params: 0
# _________________________________________________________________
# activation= relu
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2857 - accuracy: 0.8826
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2380 - accuracy: 0.8903
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2280 - accuracy: 0.9004
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2222 - accuracy: 0.9018
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2182 - accuracy: 0.9038
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2154 - accuracy: 0.9047
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2133 - accuracy: 0.9057
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2110 - accuracy: 0.9065
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2095 - accuracy: 0.9064
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2080 - accuracy: 0.9062
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2073 - accuracy: 0.9028
# Model: "sequential_1039"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3433 (Dense)           (None, 100)               4900
# _________________________________________________________________
# dense_3434 (Dense)           (None, 50)                5050
# _________________________________________________________________
# dense_3435 (Dense)           (None, 10)                510
# _________________________________________________________________
# dense_3436 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 10,482
# Trainable params: 10,482
# Non-trainable params: 0
# _________________________________________________________________
# activation= relu
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2998 - accuracy: 0.8842
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2374 - accuracy: 0.8978
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2273 - accuracy: 0.9002
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2213 - accuracy: 0.9024
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2172 - accuracy: 0.9031
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2146 - accuracy: 0.9048
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2117 - accuracy: 0.9059
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2100 - accuracy: 0.9061
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2079 - accuracy: 0.9069
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2068 - accuracy: 0.9072
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2218 - accuracy: 0.8992
# Model: "sequential_1040"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3437 (Dense)           (None, 100)               4900
# _________________________________________________________________
# dense_3438 (Dense)           (None, 50)                5050
# _________________________________________________________________
# dense_3439 (Dense)           (None, 10)                510
# _________________________________________________________________
# dense_3440 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 10,482
# Trainable params: 10,482
# Non-trainable params: 0
# _________________________________________________________________
# activation= relu
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3332 - accuracy: 0.8772
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2467 - accuracy: 0.8938
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2332 - accuracy: 0.8974
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2267 - accuracy: 0.9002
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2223 - accuracy: 0.9019
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2190 - accuracy: 0.9029
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2162 - accuracy: 0.9039
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2141 - accuracy: 0.9048
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2123 - accuracy: 0.9057
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2107 - accuracy: 0.9055
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2186 - accuracy: 0.9043
# Model: "sequential_1041"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3441 (Dense)           (None, 100)               4900
# _________________________________________________________________
# dense_3442 (Dense)           (None, 50)                5050
# _________________________________________________________________
# dense_3443 (Dense)           (None, 10)                510
# _________________________________________________________________
# dense_3444 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 10,482
# Trainable params: 10,482
# Non-trainable params: 0
# _________________________________________________________________
# activation= relu
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.3154 - accuracy: 0.8843
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2463 - accuracy: 0.8947
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2340 - accuracy: 0.8991
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2268 - accuracy: 0.9017
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2219 - accuracy: 0.9034
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2185 - accuracy: 0.9044
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2153 - accuracy: 0.9057
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2135 - accuracy: 0.9068
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2111 - accuracy: 0.9061
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2092 - accuracy: 0.9081
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2128 - accuracy: 0.9058
# Model: "sequential_1042"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3445 (Dense)           (None, 100)               4900
# _________________________________________________________________
# dense_3446 (Dense)           (None, 50)                5050
# _________________________________________________________________
# dense_3447 (Dense)           (None, 10)                510
# _________________________________________________________________
# dense_3448 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 10,482
# Trainable params: 10,482
# Non-trainable params: 0
# _________________________________________________________________
# activation= relu
# Epoch 1/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2934 - accuracy: 0.8879
# Epoch 2/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2445 - accuracy: 0.8942
# Epoch 3/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2335 - accuracy: 0.8988
# Epoch 4/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2280 - accuracy: 0.9011
# Epoch 5/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2240 - accuracy: 0.9032
# Epoch 6/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2209 - accuracy: 0.9035
# Epoch 7/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2183 - accuracy: 0.9053
# Epoch 8/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2161 - accuracy: 0.9053
# Epoch 9/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2143 - accuracy: 0.9055
# Epoch 10/10
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2124 - accuracy: 0.9061
# 227/227 [==============================] - 0s 2ms/step - loss: 0.2135 - accuracy: 0.9039
# Model: "sequential_1043"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3449 (Dense)           (None, 100)               4900
# _________________________________________________________________
# dense_3450 (Dense)           (None, 50)                5050
# _________________________________________________________________
# dense_3451 (Dense)           (None, 10)                510
# _________________________________________________________________
# dense_3452 (Dense)           (None, 2)                 22
# =================================================================
# Total params: 10,482
# Trainable params: 10,482
# Non-trainable params: 0
# _________________________________________________________________
# activation= tanh
# Epoch 1/10
# 1131/1131 [==============================] - 2s 2ms/step - loss: 0.2612 - accuracy: 0.8933
# Epoch 2/10
# 1131/1131 [==============================] - 2s 2ms/step - loss: 0.2315 - accuracy: 0.9017
# Epoch 3/10
# 1131/1131 [==============================] - 2s 2ms/step - loss: 0.2249 - accuracy: 0.9029
# Epoch 4/10
# 1131/1131 [==============================] - 2s 2ms/step - loss: 0.2217 - accuracy: 0.9033
# Epoch 5/10
# 1131/1131 [==============================] - 2s 2ms/step - loss: 0.2193 - accuracy: 0.9039
# Epoch 6/10
# 1131/1131 [==============================] - 2s 2ms/step - loss: 0.2180 - accuracy: 0.9029
# Epoch 7/10
# 1131/1131 [==============================] - 2s 2ms/step - loss: 0.2164 - accuracy: 0.9046
# Epoch 8/10
# 1131/1131 [==============================] - 2s 2ms/step - loss: 0.2153 - accuracy: 0.9047
# Epoch 9/10
# 1131/1131 [==============================] - 2s 2ms/step - loss: 0.2143 - accuracy: 0.9060
# Epoch 10/10
# 1131/1131 [==============================] - 3s 2ms/step - loss: 0.2135 - accuracy: 0.9056
# GridSearchCV(estimator=<tensorflow.python.keras.wrappers.scikit_learn.KerasClassifier object at 0x7faecf045af0>,
#              param_grid=[{'activation': ['sigmoid', 'tanh', 'relu'],
#                           'hidden_layer_sizes': [(10,), (20,), (20, 20),
#                                                  (50, 50), (20, 10, 5),
#                                                  (40, 20, 5), (100, 50, 10)]}])
# time: 29min 54s

# %%
grid_search.best_params_
# Out:
# {'activation': 'tanh', 'hidden_layer_sizes': (100, 50, 10)}
# time: 6.01 ms

# %%
y_previsto = grid_search.best_estimator_.predict(X_teste)
print("Best MLPKerasTF:")
print("Acurácia: ", accuracy_score(y_teste,y_previsto))
print("Precisão: ", precision_score(y_teste,y_previsto))
print("Recall:   ", recall_score(y_teste,y_previsto))
print("F1 Score: ", f1_score(y_teste,y_previsto))
# Out:
# Best MLPKerasTF:
# Acurácia:  0.9046776512219397
# Precisão:  0.6512549537648613
# Recall:    0.45187901008249315
# F1 Score:  0.5335497835497836
# time: 258 ms

# %% [markdown]
# ## Criando um modelo complexo

# %%
# construção de um modelo Deep & Wide
# para mais informações: https://arxiv.org/abs/1606.07792

input_  = keras.layers.Input(shape=X_treino.shape[1:])
hidden1 = keras.layers.Dense(100,activation="tanh")(input_)
hidden2 = keras.layers.Dense(50,activation="tanh")(hidden1)
hidden3 = keras.layers.Dense(10,activation="tanh")(hidden2)
concat  = keras.layers.Concatenate()([input_,hidden3])
output  = keras.layers.Dense(1,activation="sigmoid")(concat)
modelDW   = keras.Model(inputs=[input_],outputs=[output])

modelDW.compile(loss="binary_crossentropy",
                optimizer="sgd",
                metrics=["accuracy"])
# Out:
# time: 70.6 ms

# %%
import os
import time

run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
root_logdir = os.path.join(os.curdir,"logs")
run_logdir = os.path.join(root_logdir,run_id)
print("logdir = ",run_logdir)

# para salvar os logs necessários ao uso do TensorBoard
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

# para forçar o treinamento a parar antecipadamente quando não houver progresso na minimização de erro
early_stopping_cb = keras.callbacks.EarlyStopping(patience=4,restore_best_weights=True)

# para alvar periodicamente o modelo treinado e poder recomeçar o treinamento em caso de pane no meio do treinamento
checkpoint_cb     = keras.callbacks.ModelCheckpoint("model-BankMarketingData.h5") # Arquivo formato HDF5

history = modelDW.fit(X_treino, 
                      y_treino, 
                      epochs=200, 
                      validation_split=0.2,
                      callbacks=[early_stopping_cb, 
                                 checkpoint_cb,
                                 tensorboard_cb])

# para acompanhar o treinamento pelo TensorBoar:
# 1 - Rodar no console o seguinte comando dentro do diretorio do projeto: tensorboard --logdir=.\logs --port=6006
# 2 - Depois abrir a seguinte página em outra aba do navegador: http://localhost:6006/

# Pode ser usado o seguinte método para salvar manualmente um modelo:
# modelDW.save("modelDW-AcidentesTransitoPOA.h5")

# Pode ser usado o seguinte método para recuperação do modelo treinado:
# modelDW = keras.models.load_model("modelDW-AcidentesTransitoPOA.h5")
# Out:
# logdir =  ./logs/run_2020_06_27-17_20_12
# Epoch 1/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.3611 - accuracy: 0.8529 - val_loss: 0.2793 - val_accuracy: 0.8854
# Epoch 2/200
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2719 - accuracy: 0.8901 - val_loss: 0.2614 - val_accuracy: 0.8933
# Epoch 3/200
# 905/905 [==============================] - 3s 4ms/step - loss: 0.2612 - accuracy: 0.8924 - val_loss: 0.2539 - val_accuracy: 0.8963
# Epoch 4/200
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2549 - accuracy: 0.8936 - val_loss: 0.2488 - val_accuracy: 0.8988
# Epoch 5/200
# 905/905 [==============================] - 3s 4ms/step - loss: 0.2498 - accuracy: 0.8947 - val_loss: 0.2439 - val_accuracy: 0.8998
# Epoch 6/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2451 - accuracy: 0.8956 - val_loss: 0.2396 - val_accuracy: 0.9016
# Epoch 7/200
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2406 - accuracy: 0.8977 - val_loss: 0.2353 - val_accuracy: 0.9010
# Epoch 8/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2361 - accuracy: 0.8987 - val_loss: 0.2324 - val_accuracy: 0.9002
# Epoch 9/200
# 905/905 [==============================] - 2s 3ms/step - loss: 0.2319 - accuracy: 0.8987 - val_loss: 0.2272 - val_accuracy: 0.9042
# Epoch 10/200
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2279 - accuracy: 0.9011 - val_loss: 0.2241 - val_accuracy: 0.9041
# Epoch 11/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2250 - accuracy: 0.9008 - val_loss: 0.2230 - val_accuracy: 0.9019
# Epoch 12/200
# 905/905 [==============================] - 4s 4ms/step - loss: 0.2226 - accuracy: 0.9016 - val_loss: 0.2194 - val_accuracy: 0.9027
# Epoch 13/200
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2205 - accuracy: 0.9028 - val_loss: 0.2176 - val_accuracy: 0.9052
# Epoch 14/200
# 905/905 [==============================] - 2s 2ms/step - loss: 0.2185 - accuracy: 0.9037 - val_loss: 0.2159 - val_accuracy: 0.9054
# Epoch 15/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2169 - accuracy: 0.9041 - val_loss: 0.2148 - val_accuracy: 0.9059
# Epoch 16/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2154 - accuracy: 0.9047 - val_loss: 0.2136 - val_accuracy: 0.9053
# Epoch 17/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2138 - accuracy: 0.9048 - val_loss: 0.2130 - val_accuracy: 0.9054
# Epoch 18/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2127 - accuracy: 0.9050 - val_loss: 0.2116 - val_accuracy: 0.9053
# Epoch 19/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2113 - accuracy: 0.9052 - val_loss: 0.2110 - val_accuracy: 0.9059
# Epoch 20/200
# 905/905 [==============================] - 3s 4ms/step - loss: 0.2101 - accuracy: 0.9058 - val_loss: 0.2104 - val_accuracy: 0.9072
# Epoch 21/200
# 905/905 [==============================] - 3s 4ms/step - loss: 0.2091 - accuracy: 0.9064 - val_loss: 0.2121 - val_accuracy: 0.9048
# Epoch 22/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2080 - accuracy: 0.9068 - val_loss: 0.2088 - val_accuracy: 0.9074
# Epoch 23/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2068 - accuracy: 0.9075 - val_loss: 0.2078 - val_accuracy: 0.9072
# Epoch 24/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2058 - accuracy: 0.9083 - val_loss: 0.2077 - val_accuracy: 0.9066
# Epoch 25/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2049 - accuracy: 0.9083 - val_loss: 0.2080 - val_accuracy: 0.9071
# Epoch 26/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2040 - accuracy: 0.9080 - val_loss: 0.2060 - val_accuracy: 0.9075
# Epoch 27/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2029 - accuracy: 0.9098 - val_loss: 0.2071 - val_accuracy: 0.9070
# Epoch 28/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2019 - accuracy: 0.9106 - val_loss: 0.2060 - val_accuracy: 0.9068
# Epoch 29/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2010 - accuracy: 0.9105 - val_loss: 0.2053 - val_accuracy: 0.9088
# Epoch 30/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.2003 - accuracy: 0.9109 - val_loss: 0.2049 - val_accuracy: 0.9074
# Epoch 31/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.1995 - accuracy: 0.9103 - val_loss: 0.2051 - val_accuracy: 0.9074
# Epoch 32/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.1985 - accuracy: 0.9117 - val_loss: 0.2040 - val_accuracy: 0.9068
# Epoch 33/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.1977 - accuracy: 0.9116 - val_loss: 0.2041 - val_accuracy: 0.9071
# Epoch 34/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.1969 - accuracy: 0.9120 - val_loss: 0.2049 - val_accuracy: 0.9072
# Epoch 35/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.1962 - accuracy: 0.9112 - val_loss: 0.2044 - val_accuracy: 0.9064
# Epoch 36/200
# 905/905 [==============================] - 3s 3ms/step - loss: 0.1955 - accuracy: 0.9124 - val_loss: 0.2058 - val_accuracy: 0.9075
# time: 1min 40s

# %%
y_previsto_rna_proba = modelDW.predict(X_teste)
y_previsto_rna_proba
# Out:
# array([[0.00029671],
#        [0.0033091 ],
#        [0.28452033],
#        ...,
#        [0.00324236],
#        [0.00095548],
#        [0.00818058]], dtype=float32)
# time: 238 ms

# %%
y_previsto_rna = y_previsto_rna_proba > 0.5
y_previsto_rna
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])
# time: 3.96 ms

# %%
print("RNA D&W:")
print("Acurácia: ", accuracy_score(y_teste,y_previsto_rna))
print("Precisão: ", precision_score(y_teste,y_previsto_rna))
print("Recall:   ", recall_score(y_teste,y_previsto_rna))
print("F1 Score: ", f1_score(y_teste,y_previsto_rna))
# Out:
# RNA D&W:
# Acurácia:  0.9050093995355524
# Precisão:  0.6530343007915568
# Recall:    0.4537121906507791
# F1 Score:  0.5354245538128719
# time: 28.5 ms
